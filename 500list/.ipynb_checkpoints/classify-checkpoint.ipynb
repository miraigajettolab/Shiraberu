# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('n5.csv', index_col=0)

df
# Out:
# Empty DataFrame
# Columns: []
# Index: [右, 雨, 円, 下, 何, 火, 外, 学, 間, 気, 休, 金, 九, 月, 見, 五, 午, 後, 語, 校, 行, 高, 国, 今, 左, 三, 山, 四, 子, 時, 七, 車, 十, 出, 書, 女, 小, 上, 食, 人, 水, 生, 西, 先, 千, 川, 前, 大, 男, 中, 長, 天, 電, 土, 東, 読, 南, 二, 日, 入, 年, 白, 八, 半, 百, 父, 聞, 母, 北, 本, 毎, 万, 名, 木, 友, 来, 六, 話]
#
# [78 rows x 0 columns]
